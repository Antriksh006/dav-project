# %%
import pandas as pd
import numpy as np
import os

# %%
data = pd.read_csv('PPMI_DL/dat_csv/SPECT_180430_4_30_2018.csv')
data
# Out:
#       Image Data ID  Subject            Group Sex  Age  Visit Modality  \
# 0            770315    17608        Prodromal   M   62      5    SPECT
# 1            323662     3000          Control   F   69      0    SPECT
# 2            504827     3001               PD   M   69     11    SPECT
# 3            449434     3001               PD   M   68     91    SPECT
# 4            419651     3001               PD   M   67      7    SPECT
# ...             ...      ...              ...  ..  ...    ...      ...
# 1712         504421    51440     GenCohort PD   M   70      0    SPECT
# 1713         912277    51440     GenCohort PD   M   72      7    SPECT
# 1714         679879    51867  GenCohort Unaff   F   65      0    SPECT
# 1715         846391    53677  GenCohort Unaff   F   63      0    SPECT
# 1716         846210    57605  GenCohort Unaff   F   65      0    SPECT
#
#                 Description       Type   Acq Date Format Downloaded
# ...

# %%
# Extract the Image Data ID column
image_data_ids = data['Subject']

# Convert the IDs to a comma-separated string
ids_string = ','.join(map(str, image_data_ids))

# Write the string to a text file
with open('subject_data_ids.txt', 'w') as file:
    file.write(ids_string)
